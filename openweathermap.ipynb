# %%
import toml

with open("api_keys.toml") as f:
    api_keys = toml.load(f)
api_keys["openweathermap"]
# Out:
# 'e555a6353482760719121abf23e2f7d5'

# %% [markdown]
# とりあえず取得を試す。 https://openweathermap.org/api/hourly-forecast#example_JSON
#
# Free callを極力消費しないように、cache付きのrequestsを使え。

# %%
import requests_cache

# デバッグのためのツール
from icecream import ic

# Kanagawa Environmental Research Center
KERC_location = dict(lat=35.3475607, lon=139.3514103)

# cached session prepare
cache_session = requests_cache.CachedSession("openweathermap")

# One Call API 3.0, available for free.
URL = "https://pro.openweathermap.org/data/3.0/onecall?lat={lat}&lon={lon}&appid={API_key}"

url = URL.format(lon = KERC_location["lon"], lat=KERC_location["lat"], API_key = api_keys["openweathermap"])

jsondata = cache_session.get(url).json()
ic(jsondata)
# Out:
# ic| jsondata: {'alerts': [{'description': '',
#                            'end': 1738422000,
#                            'event': '乾燥注意報',
#                            'sender_name': 'JMA',
#                            'start': 1738249201,
#                            'tags': ['Air quality']}],
#                'current': {'clouds': 67,
#                            'dew_point': 276.32,
#                            'dt': 1738388212,
#                            'feels_like': 284.02,
#                            'humidity': 54,
#                            'pressure': 1020,
#                            'sunrise': 1738359739,
#                            'sunset': 1738397390,
#                            'temp': 285.34,
#                            'uvi': 0.48,
#                            'visibility': 10000,
#                            'weather': [{'description': 'broken clouds',
#                                         'icon': '04d',
#                                         'id': 803,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 139,
#                            'wind_gust': 2.28,
#                            'wind_speed': 2.96},
#                'daily': [{'clouds': 73,
#                           'dew_point': 271.4,
#                           'dt': 1738375200,
#                           'feels_like': {'day': 281.09,
#                                          'eve': 282.52,
#                                          'morn': 278.04,
#                                          'night': 280.95},
#                           'humidity': 46,
#                           'moon_phase': 0.09,
#                           'moonrise': 1738365780,
#                           'moonset': 1738408440,
#                           'pop': 0.56,
#                           'pressure': 1022,
#                           'rain': 0.2,
#                           'summary': 'You can expect partly cloudy in the morning, with rain '
#                                      'in the afternoon',
#                           'sunrise': 1738359739,
#                           'sunset': 1738397390,
#                           'temp': {'day': 282.16,
#                                    'eve': 284.02,
#                                    'max': 285.34,
#                                    'min': 279.2,
#                                    'morn': 279.53,
#                                    'night': 280.95},
#                           'uvi': 2.11,
#                           'weather': [{'description': 'light rain',
#                                        'icon': '10d',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                           'wind_deg': 21,
#                           'wind_gust': 3.45,
#                           'wind_speed': 3.2},
#                          {'clouds': 100,
#                           'dew_point': 276.37,
#                           'dt': 1738461600,
#                           'feels_like': {'day': 272.84,
#                                          'eve': 275.72,
#                                          'morn': 272.75,
#                                          'night': 275.31},
#                           'humidity': 94,
#                           'moon_phase': 0.13,
#                           'moonrise': 1738453860,
#                           'moonset': 1738498980,
#                           'pop': 1,
#                           'pressure': 1017,
#                           'rain': 15.12,
#                           'summary': 'The day will start with rain through the late morning '
#                                      'hours, transitioning to partly cloudy',
#                           'sunrise': 1738446094,
#                           'sunset': 1738483853,
#                           'temp': {'day': 277.63,
#                                    'eve': 279.53,
#                                    'max': 280.41,
#                                    'min': 276.98,
#                                    'morn': 277.5,
#                                    'night': 278.1},
#                           'uvi': 1.27,
#                           'weather': [{'description': 'moderate rain',
#                                        'icon': '10d',
#                                        'id': 501,
#                                        'main': 'Rain'}],
#                           'wind_deg': 357,
#                           'wind_gust': 11.47,
#                           'wind_speed': 7.67},
#                          {'clouds': 100,
#                           'dew_point': 275.4,
#                           'dt': 1738548000,
#                           'feels_like': {'day': 276.51,
#                                          'eve': 280.04,
#                                          'morn': 275.37,
#                                          'night': 278.75},
#                           'humidity': 83,
#                           'moon_phase': 0.17,
#                           'moonrise': 1738541940,
#                           'moonset': 1738589580,
#                           'pop': 0.85,
#                           'pressure': 1013,
#                           'rain': 0.43,
#                           'summary': 'Expect a day of partly cloudy with rain',
#                           'sunrise': 1738532447,
#                           'sunset': 1738570316,
#                           'temp': {'day': 278.45,
#                                    'eve': 280.04,
#                                    'max': 280.57,
#                                    'min': 278.3,
#                                    'morn': 278.52,
#                                    'night': 280.26},
#                           'uvi': 0.9,
#                           'weather': [{'description': 'light rain',
#                                        'icon': '10d',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                           'wind_deg': 359,
#                           'wind_gust': 5.19,
#                           'wind_speed': 4.16},
#                          {'clouds': 100,
#                           'dew_point': 275.18,
#                           'dt': 1738634400,
#                           'feels_like': {'day': 278.12,
#                                          'eve': 276.04,
#                                          'morn': 277.84,
#                                          'night': 275.04},
#                           'humidity': 83,
#                           'moon_phase': 0.21,
#                           'moonrise': 1738630140,
#                           'moonset': 1738680240,
#                           'pop': 1,
#                           'pressure': 998,
#                           'rain': 0.76,
#                           'summary': 'Expect a day of partly cloudy with rain',
#                           'sunrise': 1738618799,
#                           'sunset': 1738656778,
#                           'temp': {'day': 278.12,
#                                    'eve': 279.84,
#                                    'max': 282.67,
#                                    'min': 278.12,
#                                    'morn': 278.69,
#                                    'night': 278.6},
#                           'uvi': 2.81,
#                           'weather': [{'description': 'light rain',
#                                        'icon': '10d',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                           'wind_deg': 241,
#                           'wind_gust': 7.73,
#                           'wind_speed': 7.92},
#                          {'clouds': 28,
#                           'dew_point': 263.12,
#                           'dt': 1738720800,
#                           'feels_like': {'day': 275.16,
#                                          'eve': 271.86,
#                                          'morn': 272.54,
#                                          'night': 270.6},
#                           'humidity': 32,
#                           'moon_phase': 0.25,
#                           'moonrise': 1738718460,
#                           'moonset': 0,
#                           'pop': 0.42,
#                           'pressure': 1003,
#                           'rain': 0.31,
#                           'summary': 'Expect a day of partly cloudy with rain',
#                           'sunrise': 1738705149,
#                           'sunset': 1738743240,
#                           'temp': {'day': 279.54,
#                                    'eve': 277.68,
#                                    'max': 280.09,
#                                    'min': 275.76,
#                                    'morn': 275.76,
#                                    'night': 276.52},
#                           'uvi': 2.57,
#                           'weather': [{'description': 'light rain',
#                                        'icon': '10d',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                           'wind_deg': 249,
#                           'wind_gust': 12.05,
#                           'wind_speed': 10.98},
#                          {'clouds': 30,
#                           'dew_point': 263.6,
#                           'dt': 1738807200,
#                           'feels_like': {'day': 275.41,
#                                          'eve': 278.98,
#                                          'morn': 270.23,
#                                          'night': 273.98},
#                           'humidity': 34,
#                           'moon_phase': 0.28,
#                           'moonrise': 1738807200,
#                           'moonset': 1738770960,
#                           'pop': 0,
#                           'pressure': 1007,
#                           'summary': 'The day will start with clear sky through the late '
#                                      'morning hours, transitioning to partly cloudy',
#                           'sunrise': 1738791497,
#                           'sunset': 1738829702,
#                           'temp': {'day': 279.06,
#                                    'eve': 278.98,
#                                    'max': 279.87,
#                                    'min': 275.67,
#                                    'morn': 275.67,
#                                    'night': 277.49},
#                           'uvi': 3,
#                           'weather': [{'description': 'scattered clouds',
#                                        'icon': '03d',
#                                        'id': 802,
#                                        'main': 'Clouds'}],
#                           'wind_deg': 254,
#                           'wind_gust': 9.81,
#                           'wind_speed': 9.59},
#                          {'clouds': 0,
#                           'dew_point': 261.92,
#                           'dt': 1738893600,
#                           'feels_like': {'day': 279.43,
#                                          'eve': 278.1,
#                                          'morn': 273.81,
#                                          'night': 279.02},
#                           'humidity': 27,
#                           'moon_phase': 0.31,
#                           'moonrise': 1738896360,
#                           'moonset': 1738861620,
#                           'pop': 0,
#                           'pressure': 1016,
#                           'summary': 'Expect a day of partly cloudy with clear spells',
#                           'sunrise': 1738877845,
#                           'sunset': 1738916164,
#                           'temp': {'day': 280.4,
#                                    'eve': 280.03,
#                                    'max': 281.17,
#                                    'min': 275.91,
#                                    'morn': 275.91,
#                                    'night': 279.02},
#                           'uvi': 3,
#                           'weather': [{'description': 'clear sky',
#                                        'icon': '01d',
#                                        'id': 800,
#                                        'main': 'Clear'}],
#                           'wind_deg': 135,
#                           'wind_gust': 3.28,
#                           'wind_speed': 4.62},
#                          {'clouds': 0,
#                           'dew_point': 271.77,
#                           'dt': 1738980000,
#                           'feels_like': {'day': 280.49,
#                                          'eve': 281.84,
#                                          'morn': 276.5,
#                                          'night': 280.85},
#                           'humidity': 49,
#                           'moon_phase': 0.35,
#                           'moonrise': 1738985940,
#                           'moonset': 1738952100,
#                           'pop': 0,
#                           'pressure': 1022,
#                           'summary': 'Expect a day of partly cloudy with clear spells',
#                           'sunrise': 1738964191,
#                           'sunset': 1739002626,
#                           'temp': {'day': 282.04,
#                                    'eve': 281.84,
#                                    'max': 282.87,
#                                    'min': 276.5,
#                                    'morn': 276.5,
#                                    'night': 280.85},
#                           'uvi': 3,
#                           'weather': [{'description': 'clear sky',
#                                        'icon': '01d',
#                                        'id': 800,
#                                        'main': 'Clear'}],
#                           'wind_deg': 142,
#                           'wind_gust': 3.84,
#                           'wind_speed': 2.96}],
#                'hourly': [{'clouds': 66,
#                            'dew_point': 275.23,
#                            'dt': 1738386000,
#                            'feels_like': 283.31,
#                            'humidity': 52,
#                            'pop': 0,
#                            'pressure': 1020,
#                            'temp': 284.74,
#                            'uvi': 1.07,
#                            'visibility': 10000,
#                            'weather': [{'description': 'broken clouds',
#                                         'icon': '04d',
#                                         'id': 803,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 137,
#                            'wind_gust': 1.51,
#                            'wind_speed': 2.27},
#                           {'clouds': 67,
#                            'dew_point': 276.32,
#                            'dt': 1738389600,
#                            'feels_like': 284.02,
#                            'humidity': 54,
#                            'pop': 0,
#                            'pressure': 1020,
#                            'temp': 285.34,
#                            'uvi': 0.48,
#                            'visibility': 10000,
#                            'weather': [{'description': 'broken clouds',
#                                         'icon': '04d',
#                                         'id': 803,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 139,
#                            'wind_gust': 2.28,
#                            'wind_speed': 2.96},
#                           {'clouds': 74,
#                            'dew_point': 275.21,
#                            'dt': 1738393200,
#                            'feels_like': 283.29,
#                            'humidity': 52,
#                            'pop': 0,
#                            'pressure': 1020,
#                            'temp': 284.72,
#                            'uvi': 0.14,
#                            'visibility': 10000,
#                            'weather': [{'description': 'broken clouds',
#                                         'icon': '04d',
#                                         'id': 803,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 141,
#                            'wind_gust': 2.98,
#                            'wind_speed': 3.16},
#                           {'clouds': 80,
#                            'dew_point': 274.56,
#                            'dt': 1738396800,
#                            'feels_like': 282.52,
#                            'humidity': 52,
#                            'pop': 0,
#                            'pressure': 1020,
#                            'temp': 284.02,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'broken clouds',
#                                         'icon': '04d',
#                                         'id': 803,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 174,
#                            'wind_gust': 1.81,
#                            'wind_speed': 1.56},
#                           {'clouds': 87,
#                            'dew_point': 273.9,
#                            'dt': 1738400400,
#                            'feels_like': 281.74,
#                            'humidity': 52,
#                            'pop': 0,
#                            'pressure': 1021,
#                            'temp': 283.31,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04n',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 198,
#                            'wind_gust': 1.65,
#                            'wind_speed': 1.49},
#                           {'clouds': 93,
#                            'dew_point': 273.63,
#                            'dt': 1738404000,
#                            'feels_like': 281.9,
#                            'humidity': 53,
#                            'pop': 0,
#                            'pressure': 1021,
#                            'temp': 282.73,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04n',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 191,
#                            'wind_gust': 2.29,
#                            'wind_speed': 1.94},
#                           {'clouds': 100,
#                            'dew_point': 273.09,
#                            'dt': 1738407600,
#                            'feels_like': 281,
#                            'humidity': 55,
#                            'pop': 0,
#                            'pressure': 1021,
#                            'temp': 282.11,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04n',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 212,
#                            'wind_gust': 2.86,
#                            'wind_speed': 2.16},
#                           {'clouds': 100,
#                            'dew_point': 274.12,
#                            'dt': 1738411200,
#                            'feels_like': 280.59,
#                            'humidity': 60,
#                            'pop': 0,
#                            'pressure': 1021,
#                            'temp': 281.79,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04n',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 227,
#                            'wind_gust': 2.67,
#                            'wind_speed': 2.2},
#                           {'clouds': 100,
#                            'dew_point': 274.85,
#                            'dt': 1738414800,
#                            'feels_like': 280.45,
#                            'humidity': 65,
#                            'pop': 0.13,
#                            'pressure': 1019,
#                            'temp': 281.39,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04n',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 263,
#                            'wind_gust': 2.21,
#                            'wind_speed': 1.83},
#                           {'clouds': 100,
#                            'dew_point': 275.36,
#                            'dt': 1738418400,
#                            'feels_like': 280.95,
#                            'humidity': 69,
#                            'pop': 0.56,
#                            'pressure': 1019,
#                            'rain': {'1h': 0.2},
#                            'temp': 280.95,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'light rain',
#                                         'icon': '10n',
#                                         'id': 500,
#                                         'main': 'Rain'}],
#                            'wind_deg': 258,
#                            'wind_gust': 1.74,
#                            'wind_speed': 0.96},
#                           {'clouds': 100,
#                            'dew_point': 276.06,
#                            'dt': 1738422000,
#                            'feels_like': 280.41,
#                            'humidity': 76,
#                            'pop': 1,
#                            'pressure': 1018,
#                            'rain': {'1h': 0.42},
#                            'temp': 280.41,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'light rain',
#                                         'icon': '10n',
#                                         'id': 500,
#                                         'main': 'Rain'}],
#                            'wind_deg': 357,
#                            'wind_gust': 1.07,
#                            'wind_speed': 0.76},
#                           {'clouds': 100,
#                            'dew_point': 276.46,
#                            'dt': 1738425600,
#                            'feels_like': 278.55,
#                            'humidity': 79,
#                            'pop': 1,
#                            'pressure': 1018,
#                            'rain': {'1h': 0.5},
#                            'temp': 280.19,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'light rain',
#                                         'icon': '10n',
#                                         'id': 500,
#                                         'main': 'Rain'}],
#                            'wind_deg': 4,
#                            'wind_gust': 2.78,
#                            'wind_speed': 2.39},
#                           {'clouds': 100,
#                            'dew_point': 277.06,
#                            'dt': 1738429200,
#                            'feels_like': 277,
#                            'humidity': 85,
#                            'pop': 1,
#                            'pressure': 1017,
#                            'rain': {'1h': 0.6},
#                            'temp': 279.82,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'light rain',
#                                         'icon': '10n',
#                                         'id': 500,
#                                         'main': 'Rain'}],
#                            'wind_deg': 12,
#                            'wind_gust': 4.36,
#                            'wind_speed': 4.12},
#                           {'clouds': 100,
#                            'dew_point': 277.44,
#                            'dt': 1738432800,
#                            'feels_like': 275.57,
#                            'humidity': 90,
#                            'pop': 1,
#                            'pressure': 1016,
#                            'rain': {'1h': 1.19},
#                            'temp': 279.26,
#                            'uvi': 0,
#                            'visibility': 6543,
#                            'weather': [{'description': 'moderate rain',
#                                         'icon': '10n',
#                                         'id': 501,
#                                         'main': 'Rain'}],
#                            'wind_deg': 10,
#                            'wind_gust': 6.21,
#                            'wind_speed': 5.72},
#                           {'clouds': 100,
#                            'dew_point': 276.67,
#                            'dt': 1738436400,
#                            'feels_like': 274.2,
#                            'humidity': 92,
#                            'pop': 1,
#                            'pressure': 1017,
#                            'rain': {'1h': 1.93},
#                            'temp': 278.33,
#                            'uvi': 0,
#                            'visibility': 2690,
#                            'weather': [{'description': 'moderate rain',
#                                         'icon': '10n',
#                                         'id': 501,
#                                         'main': 'Rain'}],
#                            'wind_deg': 4,
#                            'wind_gust': 6.81,
#                            'wind_speed': 6.18},
#                           {'clouds': 100,
#                            'dew_point': 275.87,
#                            'dt': 1738440000,
#                            'feels_like': 272.75,
#                            'humidity': 91,
#                            'pop': 1,
#                            'pressure': 1016,
#                            'rain': {'1h': 1.73},
#                            'temp': 277.5,
#                            'uvi': 0,
#                            'visibility': 3483,
#                            'weather': [{'description': 'moderate rain',
#                                         'icon': '10n',
#                                         'id': 501,
#                                         'main': 'Rain'}],
#                            'wind_deg': 9,
#                            'wind_gust': 9.38,
#                            'wind_speed': 7.2},
#                           {'clouds': 100,
#                            'dew_point': 275.87,
#                            'dt': 1738443600,
#                            'feels_like': 272.92,
#                            'humidity': 93,
#                            'pop': 1,
#                            'pressure': 1017,
#                            'rain': {'1h': 1.95},
#                            'temp': 277.27,
#                            'uvi': 0,
#                            'visibility': 162,
#                            'weather': [{'description': 'moderate rain',
#                                         'icon': '10n',
#                                         'id': 501,
#                                         'main': 'Rain'}],
#                            'wind_deg': 0,
#                            'wind_gust': 8.89,
#                            'wind_speed': 6.02},
#                           {'clouds': 100,
#                            'dew_point': 275.8,
#                            'dt': 1738447200,
#                            'feels_like': 272.35,
#                            'humidity': 94,
#                            'pop': 1,
#                            'pressure': 1017,
#                            'rain': {'1h': 3.06},
#                            'temp': 276.98,
#                            'uvi': 0,
#                            'visibility': 270,
#                            'weather': [{'description': 'moderate rain',
#                                         'icon': '10d',
#                                         'id': 501,
#                                         'main': 'Rain'}],
#                            'wind_deg': 2,
#                            'wind_gust': 9.83,
#                            'wind_speed': 6.51},
#                           {'clouds': 100,
#                            'dew_point': 275.74,
#                            'dt': 1738450800,
#                            'feels_like': 272.41,
#                            'humidity': 94,
#                            'pop': 1,
#                            'pressure': 1017,
#                            'rain': {'1h': 1.83},
#                            'temp': 277.05,
#                            'uvi': 0.24,
#                            'visibility': 545,
#                            'weather': [{'description': 'moderate rain',
#                                         'icon': '10d',
#                                         'id': 501,
#                                         'main': 'Rain'}],
#                            'wind_deg': 1,
#                            'wind_gust': 10.06,
#                            'wind_speed': 6.57},
#                           {'clouds': 100,
#                            'dew_point': 275.79,
#                            'dt': 1738454400,
#                            'feels_like': 272.88,
#                            'humidity': 92,
#                            'pop': 1,
#                            'pressure': 1018,
#                            'rain': {'1h': 1.11},
#                            'temp': 277.42,
#                            'uvi': 0.46,
#                            'visibility': 4725,
#                            'weather': [{'description': 'moderate rain',
#                                         'icon': '10d',
#                                         'id': 501,
#                                         'main': 'Rain'}],
#                            'wind_deg': 355,
#                            'wind_gust': 9.74,
#                            'wind_speed': 6.58},
#                           {'clouds': 100,
#                            'dew_point': 276.22,
#                            'dt': 1738458000,
#                            'feels_like': 273.12,
#                            'humidity': 92,
#                            'pop': 1,
#                            'pressure': 1018,
#                            'rain': {'1h': 0.61},
#                            'temp': 277.7,
#                            'uvi': 1.11,
#                            'visibility': 10000,
#                            'weather': [{'description': 'light rain',
#                                         'icon': '10d',
#                                         'id': 500,
#                                         'main': 'Rain'}],
#                            'wind_deg': 0,
#                            'wind_gust': 10.22,
#                            'wind_speed': 6.9},
#                           {'clouds': 100,
#                            'dew_point': 276.37,
#                            'dt': 1738461600,
#                            'feels_like': 272.84,
#                            'humidity': 94,
#                            'pop': 1,
#                            'pressure': 1017,
#                            'rain': {'1h': 0.19},
#                            'temp': 277.63,
#                            'uvi': 1.27,
#                            'visibility': 5821,
#                            'weather': [{'description': 'light rain',
#                                         'icon': '10d',
#                                         'id': 500,
#                                         'main': 'Rain'}],
#                            'wind_deg': 360,
#                            'wind_gust': 11.4,
#                            'wind_speed': 7.43},
#                           {'clouds': 100,
#                            'dew_point': 276.23,
#                            'dt': 1738465200,
#                            'feels_like': 273.31,
#                            'humidity': 91,
#                            'pop': 0.8,
#                            'pressure': 1016,
#                            'temp': 278.06,
#                            'uvi': 0.92,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04d',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 357,
#                            'wind_gust': 11.47,
#                            'wind_speed': 7.67},
#                           {'clouds': 100,
#                            'dew_point': 276.2,
#                            'dt': 1738468800,
#                            'feels_like': 273.88,
#                            'humidity': 88,
#                            'pop': 0.8,
#                            'pressure': 1015,
#                            'temp': 278.47,
#                            'uvi': 0.76,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04d',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 1,
#                            'wind_gust': 11.36,
#                            'wind_speed': 7.57},
#                           {'clouds': 100,
#                            'dew_point': 275.77,
#                            'dt': 1738472400,
#                            'feels_like': 275.08,
#                            'humidity': 81,
#                            'pop': 0.8,
#                            'pressure': 1016,
#                            'temp': 279.3,
#                            'uvi': 0.68,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04d',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 5,
#                            'wind_gust': 10.14,
#                            'wind_speed': 7.17},
#                           {'clouds': 100,
#                            'dew_point': 275.76,
#                            'dt': 1738476000,
#                            'feels_like': 275.6,
#                            'humidity': 78,
#                            'pop': 0.78,
#                            'pressure': 1015,
#                            'temp': 279.74,
#                            'uvi': 0.42,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04d',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 12,
#                            'wind_gust': 10.14,
#                            'wind_speed': 7.32},
#                           {'clouds': 100,
#                            'dew_point': 275.5,
#                            'dt': 1738479600,
#                            'feels_like': 276.17,
#                            'humidity': 76,
#                            'pop': 0,
#                            'pressure': 1016,
#                            'temp': 279.88,
#                            'uvi': 0.14,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04d',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 16,
#                            'wind_gust': 8.62,
#                            'wind_speed': 6.18},
#                           {'clouds': 100,
#                            'dew_point': 275.54,
#                            'dt': 1738483200,
#                            'feels_like': 275.72,
#                            'humidity': 78,
#                            'pop': 0,
#                            'pressure': 1016,
#                            'temp': 279.53,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04d',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 18,
#                            'wind_gust': 8.22,
#                            'wind_speed': 6.21},
#                           {'clouds': 84,
#                            'dew_point': 275.3,
#                            'dt': 1738486800,
#                            'feels_like': 275.37,
#                            'humidity': 79,
#                            'pop': 0,
#                            'pressure': 1016,
#                            'temp': 279.03,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'broken clouds',
#                                         'icon': '04n',
#                                         'id': 803,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 13,
#                            'wind_gust': 7.53,
#                            'wind_speed': 5.5},
#                           {'clouds': 74,
#                            'dew_point': 275,
#                            'dt': 1738490400,
#                            'feels_like': 275.37,
#                            'humidity': 79,
#                            'pop': 0,
#                            'pressure': 1016,
#                            'temp': 278.7,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'broken clouds',
#                                         'icon': '04n',
#                                         'id': 803,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 10,
#                            'wind_gust': 6.77,
#                            'wind_speed': 4.6},
#                           {'clouds': 70,
#                            'dew_point': 274.65,
#                            'dt': 1738494000,
#                            'feels_like': 275.2,
#                            'humidity': 79,
#                            'pop': 0,
#                            'pressure': 1017,
#                            'temp': 278.44,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'broken clouds',
#                                         'icon': '04n',
#                                         'id': 803,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 355,
#                            'wind_gust': 6.12,
#                            'wind_speed': 4.3},
#                           {'clouds': 72,
#                            'dew_point': 274.49,
#                            'dt': 1738497600,
#                            'feels_like': 275.05,
#                            'humidity': 79,
#                            'pop': 0,
#                            'pressure': 1016,
#                            'temp': 278.19,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'broken clouds',
#                                         'icon': '04n',
#                                         'id': 803,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 360,
#                            'wind_gust': 5.97,
#                            'wind_speed': 4.02},
#                           {'clouds': 65,
#                            'dew_point': 274.03,
#                            'dt': 1738501200,
#                            'feels_like': 275.3,
#                            'humidity': 78,
#                            'pop': 0,
#                            'pressure': 1016,
#                            'temp': 277.92,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'broken clouds',
#                                         'icon': '04n',
#                                         'id': 803,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 348,
#                            'wind_gust': 4.58,
#                            'wind_speed': 3.11},
#                           {'clouds': 83,
#                            'dew_point': 273.88,
#                            'dt': 1738504800,
#                            'feels_like': 275.31,
#                            'humidity': 76,
#                            'pop': 0,
#                            'pressure': 1016,
#                            'temp': 278.1,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'broken clouds',
#                                         'icon': '04n',
#                                         'id': 803,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 340,
#                            'wind_gust': 4.48,
#                            'wind_speed': 3.41},
#                           {'clouds': 88,
#                            'dew_point': 273.87,
#                            'dt': 1738508400,
#                            'feels_like': 275.87,
#                            'humidity': 75,
#                            'pop': 0,
#                            'pressure': 1017,
#                            'temp': 278.44,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04n',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 337,
#                            'wind_gust': 4.2,
#                            'wind_speed': 3.19},
#                           {'clouds': 91,
#                            'dew_point': 273.93,
#                            'dt': 1738512000,
#                            'feels_like': 276.7,
#                            'humidity': 73,
#                            'pop': 0,
#                            'pressure': 1016,
#                            'temp': 278.83,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04n',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 359,
#                            'wind_gust': 3.78,
#                            'wind_speed': 2.7},
#                           {'clouds': 93,
#                            'dew_point': 273.92,
#                            'dt': 1738515600,
#                            'feels_like': 276.38,
#                            'humidity': 73,
#                            'pop': 0,
#                            'pressure': 1016,
#                            'temp': 278.7,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04n',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 358,
#                            'wind_gust': 3.9,
#                            'wind_speed': 2.91},
#                           {'clouds': 94,
#                            'dew_point': 274.09,
#                            'dt': 1738519200,
#                            'feels_like': 276.51,
#                            'humidity': 74,
#                            'pop': 0,
#                            'pressure': 1015,
#                            'temp': 278.83,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04n',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 359,
#                            'wind_gust': 3.89,
#                            'wind_speed': 2.95},
#                           {'clouds': 100,
#                            'dew_point': 274.35,
#                            'dt': 1738522800,
#                            'feels_like': 276.15,
#                            'humidity': 76,
#                            'pop': 0,
#                            'pressure': 1014,
#                            'temp': 278.73,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04n',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 6,
#                            'wind_gust': 4.19,
#                            'wind_speed': 3.29},
#                           {'clouds': 100,
#                            'dew_point': 274.47,
#                            'dt': 1738526400,
#                            'feels_like': 275.37,
#                            'humidity': 78,
#                            'pop': 0,
#                            'pressure': 1014,
#                            'temp': 278.52,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04n',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 359,
#                            'wind_gust': 5.19,
#                            'wind_speed': 4.16},
#                           {'clouds': 100,
#                            'dew_point': 274.24,
#                            'dt': 1738530000,
#                            'feels_like': 275.47,
#                            'humidity': 77,
#                            'pop': 0,
#                            'pressure': 1014,
#                            'temp': 278.3,
#                            'uvi': 0,
#                            'visibility': 10000,
#                            'weather': [{'description': 'overcast clouds',
#                                         'icon': '04n',
#                                         'id': 804,
#                                         'main': 'Clouds'}],
#                            'wind_deg': 7,
#                            'wind_gust': 4.53,
#                            'wind_speed': 3.54},
#                           {'clouds': 100,
#                            'dew_point': 274.17,
#                            'dt': 1738533600,
#                            'feels_like': 275.49,
#                            'humidity': 77,
#                            'pop': 0,
#                            'pressure': 1014,
#                            'temp': 278.33,
# ...
#    'wind_speed': 7.43,
#    'wind_deg': 360,
#    'wind_gust': 11.4,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 1,
#    'rain': {'1h': 0.19}},
#   {'dt': 1738465200,
#    'temp': 278.06,
#    'feels_like': 273.31,
#    'pressure': 1016,
#    'humidity': 91,
#    'dew_point': 276.23,
#    'uvi': 0.92,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 7.67,
#    'wind_deg': 357,
#    'wind_gust': 11.47,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.8},
#   {'dt': 1738468800,
#    'temp': 278.47,
#    'feels_like': 273.88,
#    'pressure': 1015,
#    'humidity': 88,
#    'dew_point': 276.2,
#    'uvi': 0.76,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 7.57,
#    'wind_deg': 1,
#    'wind_gust': 11.36,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.8},
#   {'dt': 1738472400,
#    'temp': 279.3,
#    'feels_like': 275.08,
#    'pressure': 1016,
#    'humidity': 81,
#    'dew_point': 275.77,
#    'uvi': 0.68,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 7.17,
#    'wind_deg': 5,
#    'wind_gust': 10.14,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.8},
#   {'dt': 1738476000,
#    'temp': 279.74,
#    'feels_like': 275.6,
#    'pressure': 1015,
#    'humidity': 78,
#    'dew_point': 275.76,
#    'uvi': 0.42,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 7.32,
#    'wind_deg': 12,
#    'wind_gust': 10.14,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.78},
#   {'dt': 1738479600,
#    'temp': 279.88,
#    'feels_like': 276.17,
#    'pressure': 1016,
#    'humidity': 76,
#    'dew_point': 275.5,
#    'uvi': 0.14,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.18,
#    'wind_deg': 16,
#    'wind_gust': 8.62,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1738483200,
#    'temp': 279.53,
#    'feels_like': 275.72,
#    'pressure': 1016,
#    'humidity': 78,
#    'dew_point': 275.54,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.21,
#    'wind_deg': 18,
#    'wind_gust': 8.22,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1738486800,
#    'temp': 279.03,
#    'feels_like': 275.37,
#    'pressure': 1016,
#    'humidity': 79,
#    'dew_point': 275.3,
#    'uvi': 0,
#    'clouds': 84,
#    'visibility': 10000,
#    'wind_speed': 5.5,
#    'wind_deg': 13,
#    'wind_gust': 7.53,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1738490400,
#    'temp': 278.7,
#    'feels_like': 275.37,
#    'pressure': 1016,
#    'humidity': 79,
#    'dew_point': 275,
#    'uvi': 0,
#    'clouds': 74,
#    'visibility': 10000,
#    'wind_speed': 4.6,
#    'wind_deg': 10,
#    'wind_gust': 6.77,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1738494000,
#    'temp': 278.44,
#    'feels_like': 275.2,
#    'pressure': 1017,
#    'humidity': 79,
#    'dew_point': 274.65,
#    'uvi': 0,
#    'clouds': 70,
#    'visibility': 10000,
#    'wind_speed': 4.3,
#    'wind_deg': 355,
#    'wind_gust': 6.12,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1738497600,
#    'temp': 278.19,
#    'feels_like': 275.05,
#    'pressure': 1016,
#    'humidity': 79,
#    'dew_point': 274.49,
#    'uvi': 0,
#    'clouds': 72,
#    'visibility': 10000,
#    'wind_speed': 4.02,
#    'wind_deg': 360,
#    'wind_gust': 5.97,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1738501200,
#    'temp': 277.92,
#    'feels_like': 275.3,
#    'pressure': 1016,
#    'humidity': 78,
#    'dew_point': 274.03,
#    'uvi': 0,
#    'clouds': 65,
#    'visibility': 10000,
#    'wind_speed': 3.11,
#    'wind_deg': 348,
#    'wind_gust': 4.58,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1738504800,
#    'temp': 278.1,
#    'feels_like': 275.31,
#    'pressure': 1016,
#    'humidity': 76,
#    'dew_point': 273.88,
#    'uvi': 0,
#    'clouds': 83,
#    'visibility': 10000,
#    'wind_speed': 3.41,
#    'wind_deg': 340,
#    'wind_gust': 4.48,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1738508400,
#    'temp': 278.44,
#    'feels_like': 275.87,
#    'pressure': 1017,
#    'humidity': 75,
#    'dew_point': 273.87,
#    'uvi': 0,
#    'clouds': 88,
#    'visibility': 10000,
#    'wind_speed': 3.19,
#    'wind_deg': 337,
#    'wind_gust': 4.2,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1738512000,
#    'temp': 278.83,
#    'feels_like': 276.7,
#    'pressure': 1016,
#    'humidity': 73,
#    'dew_point': 273.93,
#    'uvi': 0,
#    'clouds': 91,
#    'visibility': 10000,
#    'wind_speed': 2.7,
#    'wind_deg': 359,
#    'wind_gust': 3.78,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1738515600,
#    'temp': 278.7,
#    'feels_like': 276.38,
#    'pressure': 1016,
#    'humidity': 73,
#    'dew_point': 273.92,
#    'uvi': 0,
#    'clouds': 93,
#    'visibility': 10000,
#    'wind_speed': 2.91,
#    'wind_deg': 358,
#    'wind_gust': 3.9,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1738519200,
#    'temp': 278.83,
#    'feels_like': 276.51,
#    'pressure': 1015,
#    'humidity': 74,
#    'dew_point': 274.09,
#    'uvi': 0,
#    'clouds': 94,
#    'visibility': 10000,
#    'wind_speed': 2.95,
#    'wind_deg': 359,
#    'wind_gust': 3.89,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1738522800,
#    'temp': 278.73,
#    'feels_like': 276.15,
#    'pressure': 1014,
#    'humidity': 76,
#    'dew_point': 274.35,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 3.29,
#    'wind_deg': 6,
#    'wind_gust': 4.19,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1738526400,
#    'temp': 278.52,
#    'feels_like': 275.37,
#    'pressure': 1014,
#    'humidity': 78,
#    'dew_point': 274.47,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 4.16,
#    'wind_deg': 359,
#    'wind_gust': 5.19,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1738530000,
#    'temp': 278.3,
#    'feels_like': 275.47,
#    'pressure': 1014,
#    'humidity': 77,
#    'dew_point': 274.24,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 3.54,
#    'wind_deg': 7,
#    'wind_gust': 4.53,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1738533600,
#    'temp': 278.33,
#    'feels_like': 275.49,
#    'pressure': 1014,
#    'humidity': 77,
#    'dew_point': 274.17,
#    'uvi': 0.02,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 3.57,
#    'wind_deg': 6,
#    'wind_gust': 4.56,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1738537200,
#    'temp': 278.73,
#    'feels_like': 276.77,
#    'pressure': 1015,
#    'humidity': 73,
#    'dew_point': 273.86,
#    'uvi': 0.25,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 2.46,
#    'wind_deg': 357,
#    'wind_gust': 2.73,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1738540800,
#    'temp': 279.06,
#    'feels_like': 277.47,
#    'pressure': 1014,
#    'humidity': 70,
#    'dew_point': 273.53,
#    'uvi': 0.59,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 2.11,
#    'wind_deg': 355,
#    'wind_gust': 2.04,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1738544400,
#    'temp': 278.9,
#    'feels_like': 277.15,
#    'pressure': 1014,
#    'humidity': 73,
#    'dew_point': 273.91,
#    'uvi': 0.7,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 2.26,
#    'wind_deg': 332,
#    'wind_gust': 1.67,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.38},
#   {'dt': 1738548000,
#    'temp': 278.45,
#    'feels_like': 276.51,
#    'pressure': 1013,
#    'humidity': 83,
#    'dew_point': 275.4,
#    'uvi': 0.9,
#    'clouds': 100,
#    'visibility': 8495,
#    'wind_speed': 2.38,
#    'wind_deg': 348,
#    'wind_gust': 1.93,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.85,
#    'rain': {'1h': 0.32}},
#   {'dt': 1738551600,
#    'temp': 278.67,
#    'feels_like': 277.85,
#    'pressure': 1011,
#    'humidity': 82,
#    'dew_point': 275.33,
#    'uvi': 0.6,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.38,
#    'wind_deg': 3,
#    'wind_gust': 1.11,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.76,
#    'rain': {'1h': 0.11}},
#   {'dt': 1738555200,
#    'temp': 279.23,
#    'feels_like': 279.23,
#    'pressure': 1010,
#    'humidity': 78,
#    'dew_point': 275.29,
#    'uvi': 0.52,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.14,
#    'wind_deg': 40,
#    'wind_gust': 0.78,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.63}],
#  'daily': [{'dt': 1738375200,
#    'sunrise': 1738359739,
#    'sunset': 1738397390,
#    'moonrise': 1738365780,
#    'moonset': 1738408440,
#    'moon_phase': 0.09,
#    'summary': 'You can expect partly cloudy in the morning, with rain in the afternoon',
#    'temp': {'day': 282.16,
#     'min': 279.2,
#     'max': 285.34,
#     'night': 280.95,
#     'eve': 284.02,
#     'morn': 279.53},
#    'feels_like': {'day': 281.09,
#     'night': 280.95,
#     'eve': 282.52,
#     'morn': 278.04},
#    'pressure': 1022,
#    'humidity': 46,
#    'dew_point': 271.4,
#    'wind_speed': 3.2,
#    'wind_deg': 21,
#    'wind_gust': 3.45,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 73,
#    'pop': 0.56,
#    'rain': 0.2,
#    'uvi': 2.11},
#   {'dt': 1738461600,
#    'sunrise': 1738446094,
#    'sunset': 1738483853,
#    'moonrise': 1738453860,
#    'moonset': 1738498980,
#    'moon_phase': 0.13,
#    'summary': 'The day will start with rain through the late morning hours, transitioning to partly cloudy',
#    'temp': {'day': 277.63,
#     'min': 276.98,
#     'max': 280.41,
#     'night': 278.1,
#     'eve': 279.53,
#     'morn': 277.5},
#    'feels_like': {'day': 272.84,
#     'night': 275.31,
#     'eve': 275.72,
#     'morn': 272.75},
#    'pressure': 1017,
#    'humidity': 94,
#    'dew_point': 276.37,
#    'wind_speed': 7.67,
#    'wind_deg': 357,
#    'wind_gust': 11.47,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 1,
#    'rain': 15.12,
#    'uvi': 1.27},
#   {'dt': 1738548000,
#    'sunrise': 1738532447,
#    'sunset': 1738570316,
#    'moonrise': 1738541940,
#    'moonset': 1738589580,
#    'moon_phase': 0.17,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 278.45,
#     'min': 278.3,
#     'max': 280.57,
#     'night': 280.26,
#     'eve': 280.04,
#     'morn': 278.52},
#    'feels_like': {'day': 276.51,
#     'night': 278.75,
#     'eve': 280.04,
#     'morn': 275.37},
#    'pressure': 1013,
#    'humidity': 83,
#    'dew_point': 275.4,
#    'wind_speed': 4.16,
#    'wind_deg': 359,
#    'wind_gust': 5.19,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 0.85,
#    'rain': 0.43,
#    'uvi': 0.9},
#   {'dt': 1738634400,
#    'sunrise': 1738618799,
#    'sunset': 1738656778,
#    'moonrise': 1738630140,
#    'moonset': 1738680240,
#    'moon_phase': 0.21,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 278.12,
#     'min': 278.12,
#     'max': 282.67,
#     'night': 278.6,
#     'eve': 279.84,
#     'morn': 278.69},
#    'feels_like': {'day': 278.12,
#     'night': 275.04,
#     'eve': 276.04,
#     'morn': 277.84},
#    'pressure': 998,
#    'humidity': 83,
#    'dew_point': 275.18,
#    'wind_speed': 7.92,
#    'wind_deg': 241,
#    'wind_gust': 7.73,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 1,
#    'rain': 0.76,
#    'uvi': 2.81},
#   {'dt': 1738720800,
#    'sunrise': 1738705149,
#    'sunset': 1738743240,
#    'moonrise': 1738718460,
#    'moonset': 0,
#    'moon_phase': 0.25,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 279.54,
#     'min': 275.76,
#     'max': 280.09,
#     'night': 276.52,
#     'eve': 277.68,
#     'morn': 275.76},
#    'feels_like': {'day': 275.16,
#     'night': 270.6,
#     'eve': 271.86,
#     'morn': 272.54},
#    'pressure': 1003,
#    'humidity': 32,
#    'dew_point': 263.12,
#    'wind_speed': 10.98,
#    'wind_deg': 249,
#    'wind_gust': 12.05,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 28,
#    'pop': 0.42,
#    'rain': 0.31,
#    'uvi': 2.57},
#   {'dt': 1738807200,
#    'sunrise': 1738791497,
#    'sunset': 1738829702,
#    'moonrise': 1738807200,
#    'moonset': 1738770960,
#    'moon_phase': 0.28,
#    'summary': 'The day will start with clear sky through the late morning hours, transitioning to partly cloudy',
#    'temp': {'day': 279.06,
#     'min': 275.67,
#     'max': 279.87,
#     'night': 277.49,
#     'eve': 278.98,
#     'morn': 275.67},
#    'feels_like': {'day': 275.41,
#     'night': 273.98,
#     'eve': 278.98,
#     'morn': 270.23},
#    'pressure': 1007,
#    'humidity': 34,
#    'dew_point': 263.6,
#    'wind_speed': 9.59,
#    'wind_deg': 254,
#    'wind_gust': 9.81,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': 30,
#    'pop': 0,
#    'uvi': 3},
#   {'dt': 1738893600,
#    'sunrise': 1738877845,
#    'sunset': 1738916164,
#    'moonrise': 1738896360,
#    'moonset': 1738861620,
#    'moon_phase': 0.31,
#    'summary': 'Expect a day of partly cloudy with clear spells',
#    'temp': {'day': 280.4,
#     'min': 275.91,
#     'max': 281.17,
#     'night': 279.02,
#     'eve': 280.03,
#     'morn': 275.91},
#    'feels_like': {'day': 279.43,
#     'night': 279.02,
#     'eve': 278.1,
#     'morn': 273.81},
#    'pressure': 1016,
#    'humidity': 27,
#    'dew_point': 261.92,
#    'wind_speed': 4.62,
#    'wind_deg': 135,
#    'wind_gust': 3.28,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 3},
#   {'dt': 1738980000,
#    'sunrise': 1738964191,
#    'sunset': 1739002626,
#    'moonrise': 1738985940,
#    'moonset': 1738952100,
#    'moon_phase': 0.35,
#    'summary': 'Expect a day of partly cloudy with clear spells',
#    'temp': {'day': 282.04,
#     'min': 276.5,
#     'max': 282.87,
#     'night': 280.85,
#     'eve': 281.84,
#     'morn': 276.5},
#    'feels_like': {'day': 280.49,
#     'night': 280.85,
#     'eve': 281.84,
#     'morn': 276.5},
#    'pressure': 1022,
#    'humidity': 49,
#    'dew_point': 271.77,
#    'wind_speed': 2.96,
#    'wind_deg': 142,
#    'wind_gust': 3.84,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 3}],
#  'alerts': [{'sender_name': 'JMA',
#    'event': '乾燥注意報',
#    'start': 1738249201,
#    'end': 1738422000,
#    'description': '',
#    'tags': ['Air quality']}]}

# %% [markdown]
# とってきたい項目は?
#
# * 気温
# * (湿度)
# * 風速風向
# * 日照または天候コード

# %%
# OpenMeteoで取得していた項目
OPENMETEO_ITEMS = (
    "temperature_2m",
    "weather_code",
    "cloud_cover",
    "wind_speed_10m",
    "pressure_msl",
    "shortwave_radiation",
)

OPENWM_ITEMS = (
    "temp",
    "weather_code", # これは複層になってる
    "cloud_cover",
    "wind_speed_10m",
    "pressure_msl", 
    #"shortwave_radiation", # このデータはない。
    )

ic(jsondata["hourly"][0]["temp"])
ic(jsondata["hourly"][0]["weather"][0]["id"])
ic(jsondata["hourly"][0]["clouds"])
ic(jsondata["hourly"][0]["wind_speed"])
ic(jsondata["hourly"][0]["pressure"])

jsondata["hourly"][0]
# Out:
# ic| jsondata["hourly"][0]["temp"]: 284.74
# ic| jsondata["
# hourly"][0]["weather"][0]["id"]: 803
# ic| jsondata["hourly"][0]["clouds"]: 66
# ic| jsondata["hourly"][0]["wind_speed"]: 2.27
# ic| jsondata["hourly"][0]["pressure"]: 1020
# {'dt': 1738386000,
#  'temp': 284.74,
#  'feels_like': 283.31,
#  'pressure': 1020,
#  'humidity': 52,
#  'dew_point': 275.23,
#  'uvi': 1.07,
#  'clouds': 66,
#  'visibility': 10000,
#  'wind_speed': 2.27,
#  'wind_deg': 137,
#  'wind_gust': 1.51,
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'pop': 0}

# %%
import matplotlib.pyplot as plt
from  datetime import datetime
import numpy as np

keys = jsondata["hourly"][0].keys()
rec_wise = dict()
for key in keys:
    rec_wise[key] = np.array([rec[key] for rec in jsondata["hourly"]])

rec_wise["datetime"] = [datetime.fromtimestamp(x) for x in rec_wise["dt"]]


fig = plt.figure(figsize=(10,5))
plt.plot(rec_wise["datetime"], rec_wise["temp"]-273.15)
plt.ylabel("Temperature / °C")
# Out:
# Text(0, 0.5, 'Temperature / °C')
